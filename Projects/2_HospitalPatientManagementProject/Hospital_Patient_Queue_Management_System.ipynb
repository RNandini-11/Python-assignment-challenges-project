# %% [markdown]
# **Hospital Patient Queue Management System**
#
# The Hospital Patient Queue Management System is a Python-based command-line application designed to manage patient queues in a hospital.
# It utilizes object-oriented programming (OOP) principles and includes three main classes: Patient, Specialization, and OperationsManager. This project provides a simple yet effective way to handle patient data and queue management within a hospital setting.
#
# The Hospital Patient Queue Management System is an illustration of OOP concepts in Python. It consists of three primary classes, each serving a specific purpose:
#
# **Patient:**
#
# The Patient class represents an individual patient and includes the following attributes:
#
# *	name: The name of the patient.
# *	status: The patient's status, which can be 0 (normal), 1 (urgent), or 2 (super-urgent).
#
# This class provides methods for string representation and status formatting for patients.
#
# **Specialization:**
#
# The Specialization class manages patient queues within different specializations. It offers functionalities such as:
#
# *	Adding patients with various urgency levels.
# *	Retrieving the next patient from the queue.
# *	Removing patients by name.
# *	Checking queue capacity.
#
# **OperationsManager:**
# The OperationsManager class serves as the user interface for interacting with the Specialization instances. Users can perform actions like:
#
# *	Adding new patients to specializations.
# *	Listing patients in specializations.
# *	Retrieving the next patient.
# *	Removing patients.
# *	Ending the program gracefully.

# %%
class Patient:
  def __init__(self, name, status):
    self.name = name
    self.status = status

  def __str__(self):
        return f"Name: {self.name}, Status: {self.status}"

p = Patient("Raj", 2)  #p = Patient(name="Raj", status=2) think like this
print(p)                         #inside a obj - p.name = "Raj", emp.status = 2
# Out:
# Name: Raj, Status: 2

# %%
from tabulate import tabulate

class Specialization:
  def __init__(self):
    self.queue = []

  def add_patient(self, name, status):
    p=Patient(name,status)
    if p.status == 0:
      self.queue.insert(0, p)
    elif p.status == 1:
      for i in range(len(self.queue)):
        if self.queue[i].status == 2: #0
          self.queue.insert(i, p)
      self.queue.append(p)
    if p.status == 2:
        self.queue.append(p)


  def list_patients(self):
    if not self.queue:
        print("No patient found.")
        return #return immediately exits the method.
    table = []
    for p in self.queue: # p = actual patient object
        table.append([p.name, p.status])
    print("\n======= Patient List =======\n")
    print(tabulate(table, headers=["Name", "Status"], tablefmt="grid"))
    print('Patients listed successfully...!')

  def get_next_patient(self):
    if not self.queue:
        print("No patients in queue.")
        return
    patient = self.queue.pop(0)
    print(f"Next patient: {patient.name}")
    print('Retrieved successfully...!')

  def remove_patient(self, name):
    for i in range(len(self.queue)):
      if self.queue[i].name.lower() == name.lower():
        self.queue.pop(i)
        print('Patient removed successfully...!')
        return

  def check_queue_capacity(self):
      print('Queue capacity:', len(self.queue))
      return len(self.queue)

s=Specialization()
s.add_patient('John', 0)
s.add_patient('Jane', 1)
s.add_patient('Bob', 2)
s.add_patient('Alice', 0)
s.add_patient('Eve', 1)
s.list_patients()
s.get_next_patient()
s.remove_patient('Jane')
s.check_queue_capacity()
# Out:
# ======= Patient List =======
#
# +--------+----------+
# | Name   |   Status |
# +========+==========+
# | Alice  |        0 |
# +--------+----------+
# | John   |        0 |
# +--------+----------+
# | Jane   |        1 |
# +--------+----------+
# | Eve    |        1 |
# +--------+----------+
# | Bob    |        2 |
# +--------+----------+
# | Eve    |        1 |
# +--------+----------+
# Patients listed successfully...!
# Next patient: Alice
# Retrieved successfully...!
# Patient removed successfully...!
# Queue capacity: 4
# 4

# %%
class OperationsManager:
  def __init__(self):
    self.s=Specialization()
    self.menu()

  def menu(self):
    while True:
      print('\n______ Patient Menu ______')
      print('1. Add patient')
      print('2. List patients')
      print('3. Get next patient')
      print('4. Remove patient')
      print('5. Exit')

      try:
        choice = int(input('Enter your choice: '))
      except ValueError:
        print('Invalid input. Please enter a number.')
        continue


      if choice == 1:
        self.add_patient()
      elif choice == 2:
        self.list_patients()
      elif choice == 3:
        self.get_next_patient()
      elif choice == 4:
        self.remove_patient()
      elif choice == 5:
        self.exiting()
        break
      else:
        print('Invalid choice. Please try again.')

  def add_patient(self):
    try:
      no=int(input('How many patients to add:'))
    except ValueError:
      print('Invalid input!')

    for i in range(no):
      print(f'\n----Enter details of patient {i+1}----')
      name = input('Enter patient name: ')

      try:
        status = int(input('Enter patient status (0 for normal) 0-2: '))
      except ValueError:
        print('Invalid input!')
        continue

      self.s.add_patient(name,status)
      print('Patient added successfully...!')
    self.menu()

  def list_patients(self):
    self.s.list_patients()
    self.menu()

  def get_next_patient(self):
    self.s.get_next_patient()
    self.menu()

  def remove_patient(self):
    name = input('Enter patient name: ')
    self.s.remove_patient(name)
    self.menu()

  def check_queue_capacity(self):
    self.s.check_queue_capacity()
    self.menu()

  def exiting(self):
      print('Thank you for using the Operations Manager!')
      exit()

om=OperationsManager()
# Out:
# ______ Patient Menu ______
# 1. Add patient
# 2. List patients
# 3. Get next patient
# 4. Remove patient
# 5. Exit
#
# ----Enter details of patient 1----
# Patient added successfully...!
#
# ----Enter details of patient 2----
# Patient added successfully...!
#
# ----Enter details of patient 3----
# Patient added successfully...!
#
# ______ Patient Menu ______
# 1. Add patient
# 2. List patients
# 3. Get next patient
# 4. Remove patient
# 5. Exit
#
# ======= Patient List =======
#
# +--------+----------+
# | Name   |   Status |
# +========+==========+
# | Avi    |        0 |
# +--------+----------+
# | Rani   |        1 |
# +--------+----------+
# | Raj    |        2 |
# +--------+----------+
# | Rani   |        1 |
# +--------+----------+
# Patients listed successfully...!
#
# ______ Patient Menu ______
# 1. Add patient
# 2. List patients
# 3. Get next patient
# 4. Remove patient
# 5. Exit
# Next patient: Avi
# Retrieved successfully...!
#
# ______ Patient Menu ______
# 1. Add patient
# 2. List patients
# 3. Get next patient
# 4. Remove patient
# 5. Exit
# Patient removed successfully...!
#
# ______ Patient Menu ______
# 1. Add patient
# 2. List patients
# 3. Get next patient
# 4. Remove patient
# 5. Exit
# Thank you for using the Operations Manager!
#
# ______ Patient Menu ______
# 1. Add patient
# 2. List patients
# 3. Get next patient
# 4. Remove patient
# 5. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 77
#      73   def exiting(self):
#      74       print('Thank you for using the Operations Manager!')
#      75       exit()
#      76
# ---> 77 om=OperationsManager()
#
# Cell In[7], line 4, in OperationsManager.__init__(self)
#       2   def __init__(self):
#       3     self.s=Specialization()
# ----> 4     self.menu()
#
# Cell In[7], line 23, in OperationsManager.menu(self)
#      19         continue
#      20
#      21
#      22       if choice == 1:
# ---> 23         self.add_patient()
#      24       elif choice == 2:
#      25         self.list_patients()
#      26       elif choice == 3:
#
# Cell In[7], line 54, in OperationsManager.add_patient(self)
#      50         continue
#      51
#      52       self.s.add_patient(name,status)
#      53       print('Patient added successfully...!')
# ---> 54     self.menu()
#
# Cell In[7], line 25, in OperationsManager.menu(self)
#      21
#      22       if choice == 1:
#      23         self.add_patient()
#      24       elif choice == 2:
# ---> 25         self.list_patients()
#      26       elif choice == 3:
#      27         self.get_next_patient()
#      28       elif choice == 4:
#
# Cell In[7], line 58, in OperationsManager.list_patients(self)
#      56   def list_patients(self):
#      57     self.s.list_patients()
# ---> 58     self.menu()
#
# Cell In[7], line 27, in OperationsManager.menu(self)
#      23         self.add_patient()
#      24       elif choice == 2:
#      25         self.list_patients()
#      26       elif choice == 3:
# ---> 27         self.get_next_patient()
#      28       elif choice == 4:
#      29         self.remove_patient()
#      30       elif choice == 5:
#
# Cell In[7], line 62, in OperationsManager.get_next_patient(self)
#      60   def get_next_patient(self):
#      61     self.s.get_next_patient()
# ---> 62     self.menu()
#
# Cell In[7], line 17, in OperationsManager.menu(self)
#      13       print('5. Exit')
#      14
#      15       try:
#      16         choice = int(input('Enter your choice: '))
# ---> 17       except ValueError:
#      18         print('Invalid input. Please enter a number.')
#      19         continue
#      20
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
